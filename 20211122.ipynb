# %% [markdown]
# <a href="https://colab.research.google.com/github/jihyekimhaha/class2021Fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; phase = 0

G = 392.00
A = 440.00
B = 493.88
C = 523.25
D = 587.33
E = 659.25
Fh = 698.46
Gh = 783.99

# %%
# 박효신 - Goodbye
# https://youtu.be/78tHFSzMPKk  0:13초~
#[멀어어져가는오후르을바라보다아0 스쳐지나가버리인그때생각이나]
notes = [G, A, G, B, C, D, C, B, A, G, A, G, B, B, 0, G ,G, A, B, A, E, A, G, A, A, 0, B, A, G, G]

durs = [0.5, 0.25, 0.25, 0.5, 0.5, 0.5, 1.0, 0.5, 0.25, 0.25, 1.0, 0.5, 0.5, 1.0, 0.5, 0.25, 0.75, 0.5, 0.25, 0.25, 0.5, 0.25, 0.25, 0.5, 0.75, 0.15, 0.5, 0.25, 0.25, 0.75]

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
